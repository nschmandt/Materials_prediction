# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import sklearn.preprocessing
import sklearn.model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
#For a Logistic Regression, let's start by examining how well it fits the cross-validated training sets.
#looping over all 9 of the classification predictions
for j in range(9):
    f_score_values=[]
    true_pos_scores=[]
    false_pos_scores=[]
    false_neg_scores=[]
    #Cross Validation Groups
    for i in range(5):
        temp=list(range(5))
        temp.remove(i)
        #this is our set that is removed from training for validation
        val=training_nonoble[i::5]
        #training set consists of the other values
        train_X=[training_nonoble[temp[0]::5], training_nonoble[temp[1]::5], training_nonoble[temp[2]::5], training_nonoble[temp[3]::5]]
        train_X=pd.concat(train_X)
        #declare the model
        model=LogisticRegression()
        #fit the model
        fit=model.fit(train_X[col_names], train_X['stabilityVec%s' % j])
        #make a prediction
        lr_prediction=fit.predict(train_X[col_names])
        temp=lr_prediction-train_X['stabilityVec%s' % j]
        false_pos=sum(temp==1)
        false_neg=sum(temp==-1)
        temp=lr_prediction+train_X['stabilityVec%s' % j]
        true_pos=sum(temp==2)
        precision=true_pos/(true_pos+false_pos)
        recall=true_pos/(true_pos+false_neg)
        f_score=2*precision*recall/(precision+recall)
        f_score_values.append(f_score)
        true_pos_scores.append(true_pos)
        false_pos_scores.append(false_pos)
        false_neg_scores.append(false_neg)
    print('for vector position %s, the f_scores for cross-validation are as follows:' % str(j+1))
    print(f_score_values)
    print('True Positives:')
    print(true_pos_scores)
    print('False Positives')
    print(false_pos_scores)
    print('False Neg (missed positives)')
    print(false_neg_scores)
# Out:
# for vector position 1, the f_scores for cross-validation are as follows:
# [0.16666666666666666, 0.10526315789473684, 0.13636363636363635, 0.1702127659574468, 0.25531914893617019]
# True Positives:
# [4, 2, 3, 4, 6]
# False Positives
# [1, 0, 2, 2, 0]
# False Neg (missed positives)
# [39, 34, 36, 37, 35]
# /home/nick/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:28: RuntimeWarning: invalid value encountered in long_scalars
# /home/nick/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:30: RuntimeWarning: invalid value encountered in double_scalars
# for vector position 2, the f_scores for cross-validation are as follows:
# [nan, nan, 0.028985507246376812, 0.10126582278481013, nan]
# True Positives:
# [0, 0, 1, 4, 0]
# False Positives
# [0, 1, 0, 1, 0]
# False Neg (missed positives)
# [74, 71, 67, 70, 65]
# for vector position 3, the f_scores for cross-validation are as follows:
# [0.57999999999999996, 0.60096153846153855, 0.61194029850746279, 0.63170731707317074, 0.60313630880579006]
# True Positives:
# [232, 250, 246, 259, 250]
# False Positives
# [97, 101, 82, 84, 92]
# False Neg (missed positives)
# [239, 231, 230, 218, 237]
# for vector position 4, the f_scores for cross-validation are as follows:
# [0.076433121019108291, 0.10666666666666666, 0.056338028169014093, 0.1234567901234568, 0.15476190476190477]
# True Positives:
# [6, 8, 4, 10, 13]
# False Positives
# [7, 5, 6, 9, 7]
# False Neg (missed positives)
# [138, 129, 128, 133, 135]
# for vector position 5, the f_scores for cross-validation are as follows:
# [0.43704775687409547, 0.47765363128491617, 0.45402298850574713, 0.48648648648648651, 0.43854748603351956]
# True Positives:
# [151, 171, 158, 171, 157]
# False Positives
# [73, 75, 78, 69, 83]
# False Neg (missed positives)
# [316, 299, 302, 292, 319]
# for vector position 6, the f_scores for cross-validation are as follows:
# [0.22093023255813954, 0.19277108433734935, 0.12195121951219512, 0.17499999999999999, 0.15476190476190477]
# True Positives:
# [19, 16, 10, 14, 13]
# False Positives
# [1, 6, 6, 3, 2]
# False Neg (missed positives)
# [133, 128, 138, 129, 140]
# for vector position 7, the f_scores for cross-validation are as follows:
# [0.28021978021978022, 0.23255813953488375, 0.23598820058997053, 0.22873900293255131, 0.22157434402332363]
# True Positives:
# [51, 40, 40, 39, 38]
# False Positives
# [20, 17, 18, 14, 14]
# False Neg (missed positives)
# [242, 247, 241, 249, 253]
# for vector position 8, the f_scores for cross-validation are as follows:
# [0.35960591133004927, 0.40969162995594716, 0.40459770114942528, 0.38770685579196223, 0.4110854503464203]
# True Positives:
# [73, 93, 88, 82, 89]
# False Positives
# [25, 41, 34, 28, 30]
# False Neg (missed positives)
# [235, 227, 225, 231, 225]
# for vector position 9, the f_scores for cross-validation are as follows:
# [0.31578947368421051, 0.38709677419354832, 0.35087719298245612, 0.41269841269841273, 0.3529411764705882]
# True Positives:
# [9, 12, 10, 13, 12]
# False Positives
# [1, 2, 2, 2, 4]
# False Neg (missed positives)
# [38, 36, 35, 35, 40]

# %%
#It's fitting better than I thought it would. Let's see how it does with the test sets.
for j in range(9):
    f_score_values=[]
    true_pos_scores=[]
    false_pos_scores=[]
    false_neg_scores=[]
    #Cross Validation Groups
    for i in range(5):
        temp=list(range(5))
        temp.remove(i)
        #this is our set that is removed from training for validation
        val=training_nonoble[i::5]
        #training set consists of the other values
        train_X=[training_nonoble[temp[0]::5], training_nonoble[temp[1]::5], training_nonoble[temp[2]::5], training_nonoble[temp[3]::5]]
        train_X=pd.concat(train_X)
        #declare the model
        model=LogisticRegression()
        #fit the model
        fit=model.fit(train_X[col_names], train_X['stabilityVec%s' % j])
        #make a prediction
        lr_prediction=fit.predict(val[col_names])
        temp=lr_prediction-val['stabilityVec%s' % j]
        false_pos=sum(temp==1)
        false_neg=sum(temp==-1)
        temp=lr_prediction+val['stabilityVec%s' % j]
        true_pos=sum(temp==2)
        precision=true_pos/(true_pos+false_pos)
        recall=true_pos/(true_pos+false_neg)
        f_score=2*precision*recall/(precision+recall)
        f_score_values.append(f_score)
        true_pos_scores.append(true_pos)
        false_pos_scores.append(false_pos)
        false_neg_scores.append(false_neg)
    print('for vector position %s, the f_scores for cross-validation are as follows:' % str(j+1))
    print(f_score_values)
    print('True Positives:')
    print(true_pos_scores)
    print('False Positives')
    print(false_pos_scores)
    print('False Neg (missed positives)')
    print(false_neg_scores)
# Out:
# /home/nick/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:27: RuntimeWarning: invalid value encountered in long_scalars
# for vector position 1, the f_scores for cross-validation are as follows:
# [0.20000000000000001, nan, nan, nan, 0.1818181818181818]
# True Positives:
# [1, 0, 0, 0, 1]
# False Positives
# [2, 0, 0, 0, 1]
# False Neg (missed positives)
# [6, 14, 11, 9, 8]
# /home/nick/anaconda3/lib/python3.6/site-packages/ipykernel/__main__.py:29: RuntimeWarning: invalid value encountered in double_scalars
# for vector position 2, the f_scores for cross-validation are as follows:
# [nan, nan, nan, nan, nan]
# True Positives:
# [0, 0, 0, 0, 0]
# False Positives
# [0, 0, 1, 1, 0]
# False Neg (missed positives)
# [14, 17, 20, 14, 23]
# for vector position 3, the f_scores for cross-validation are as follows:
# [0.55707762557077634, 0.56281407035175879, 0.56190476190476191, 0.53588516746411474, 0.54545454545454553]
# True Positives:
# [61, 56, 59, 56, 54]
# False Positives
# [31, 26, 29, 32, 33]
# False Neg (missed positives)
# [66, 61, 63, 65, 57]
# for vector position 4, the f_scores for cross-validation are as follows:
# [0.1111111111111111, 0.095238095238095233, 0.043478260869565223, 0.16216216216216214, 0.057142857142857148]
# True Positives:
# [2, 2, 1, 3, 1]
# False Positives
# [2, 1, 1, 1, 6]
# False Neg (missed positives)
# [30, 37, 43, 30, 27]
# for vector position 5, the f_scores for cross-validation are as follows:
# [0.37647058823529411, 0.42458100558659218, 0.40860215053763438, 0.3783783783783784, 0.44311377245508982]
# True Positives:
# [32, 38, 38, 35, 37]
# False Positives
# [21, 27, 24, 29, 22]
# False Neg (missed positives)
# [85, 76, 86, 86, 71]
# for vector position 6, the f_scores for cross-validation are as follows:
# [0.054054054054054064, 0.12, 0.23255813953488372, 0.088888888888888892, 0.057142857142857141]
# True Positives:
# [1, 3, 5, 2, 1]
# False Positives
# [3, 6, 1, 1, 2]
# False Neg (missed positives)
# [32, 38, 32, 40, 31]
# for vector position 7, the f_scores for cross-validation are as follows:
# [0.25, 0.24719101123595508, 0.11363636363636365, 0.14285714285714285, 0.22471910112359553]
# True Positives:
# [11, 11, 5, 6, 10]
# False Positives
# [10, 5, 4, 6, 10]
# False Neg (missed positives)
# [56, 62, 74, 66, 59]
# for vector position 8, the f_scores for cross-validation are as follows:
# [0.37168141592920356, 0.34615384615384615, 0.32432432432432429, 0.29126213592233013, 0.36697247706422015]
# True Positives:
# [21, 18, 18, 15, 20]
# False Positives
# [8, 14, 14, 9, 11]
# False Neg (missed positives)
# [63, 54, 61, 64, 58]
# for vector position 9, the f_scores for cross-validation are as follows:
# [0.3529411764705882, 0.47058823529411764, 0.11764705882352941, 0.13333333333333333, 0.40000000000000002]
# True Positives:
# [3, 4, 1, 1, 2]
# False Positives
# [1, 1, 1, 2, 0]
# False Neg (missed positives)
# [10, 8, 14, 11, 6]

# %%
#This is really not that bad. Definitely, if we were to be more thorough, we would want to explore the kernel 
#space further, with different polynomial values and different multiplication terms of different values in the 
#matrix. To some extent, my including the ratios of different terms already does this and is probably helping
#the prediction. A more mathematically thorough examination of the kernel space could yield better results.
